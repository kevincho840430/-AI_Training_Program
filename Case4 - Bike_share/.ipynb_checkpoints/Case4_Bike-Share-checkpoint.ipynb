# %%
# !pip install gdown

# %% [markdown]
# # Case4  Bike Share Demand Predict

# %% [markdown]
# # 目標:藉由歷史資料來預測未來共享腳踏車的需求量

# %% [markdown]
# # import package

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.model_selection import train_test_split
from pandas.plotting import register_matplotlib_converters
from matplotlib import pyplot as plt
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM , Dense , Dropout


Sequential
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

register_matplotlib_converters()
sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 22, 10

RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
# !gdown --id 1nPw071R3tZi4zqVcmXA6kXVTe43Ex6K3 --output london_bike_sharing.csv

# %% [markdown]
# # Read Data and Explore

# %%
df = pd.read_csv(
  "./data/london_bike_sharing.csv", 
  parse_dates=['timestamp'], 
  index_col="timestamp"
)

# %%
df.shape
# Out:
# (17414, 9)

# %%
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0
# 2015-01-04 01:00:00         0.0         1.0     3.0
# 2015-01-04 02:00:00         0.0         1.0     3.0
# 2015-01-04 03:00:00         0.0         1.0     3.0
# 2015-01-04 04:00:00         0.0         1.0     3.0

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-04 00:00:00', '2015-01-04 01:00:00',
#                '2015-01-04 02:00:00', '2015-01-04 03:00:00',
#                '2015-01-04 04:00:00', '2015-01-04 05:00:00',
#                '2015-01-04 06:00:00', '2015-01-04 07:00:00',
#                '2015-01-04 08:00:00', '2015-01-04 09:00:00',
#                ...
#                '2017-01-03 14:00:00', '2017-01-03 15:00:00',
#                '2017-01-03 16:00:00', '2017-01-03 17:00:00',
#                '2017-01-03 18:00:00', '2017-01-03 19:00:00',
#                '2017-01-03 20:00:00', '2017-01-03 21:00:00',
#                '2017-01-03 22:00:00', '2017-01-03 23:00:00'],
#               dtype='datetime64[ns]', name='timestamp', length=17414, freq=None)

# %%
#分開時間單位
df['hour'] = df.index.hour
df['day_of_month'] = df.index.day
df['day_of_week'] = df.index.dayofweek
df['month'] = df.index.month

# %%
#cnt與時間關係
plt.figure(figsize=(25,8))
sns.lineplot(x=df.index, y="cnt", data=df);

# %%
df_by_month = df.resample('M').sum()

sns.lineplot(x=df_by_month.index, y="cnt", data=df_by_month);

# %%
fig,(ax1, ax2, ax3, ax4)= plt.subplots(nrows=4)
fig.set_size_inches(18, 28)

sns.pointplot(data=df, x='hour', y='cnt', ax=ax1)
sns.pointplot(data=df, x='hour', y='cnt', hue='is_holiday', ax=ax2)
sns.pointplot(data=df, x='hour', y='cnt', hue='is_weekend', ax=ax3)
sns.pointplot(data=df, x='hour', y='cnt', hue='season', ax=ax4);

# %%
fig,(ax1, ax2)= plt.subplots(nrows=2)
fig.set_size_inches(18, 14)

sns.pointplot(data=df, x='day_of_week', y='cnt', ax=ax1)
sns.pointplot(data=df, x='day_of_week', y='cnt', hue='season', ax=ax2);

# %%
#手動切分資料
train_size = int(len(df) * 0.9)
test_size = len(df) - train_size
train, test = df.iloc[0:train_size], df.iloc[train_size:len(df)]
print(len(train), len(test))
# Out:
# 15672 1742

# %% [markdown]
# # Preprocessing
# - Ref　:　https://ithelp.ithome.com.tw/articles/10240494

# %%
from sklearn.preprocessing import StandardScaler 

f_columns = ['t1', 't2', 'hum', 'wind_speed']
#將資料做標準化
#
f_transformer = StandardScaler ()
cnt_transformer = StandardScaler ()

f_transformer = f_transformer.fit(train[f_columns].to_numpy())
cnt_transformer = cnt_transformer.fit(train[['cnt']])

train.loc[:, f_columns] = f_transformer.transform(train[f_columns].to_numpy())
train['cnt'] = cnt_transformer.transform(train[['cnt']])

test.loc[:, f_columns] = f_transformer.transform(test[f_columns].to_numpy())
test['cnt'] = cnt_transformer.transform(test[['cnt']])
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_40260\1709535596.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.loc[:, f_columns] = f_transformer.transform(train[f_columns].to_numpy())
# C:\Users\kevin\AppData\Local\Temp\ipykernel_40260\1709535596.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['cnt'] = cnt_transformer.transform(train[['cnt']])
# C:\Users\kevin\AppData\Local\Temp\ipykernel_40260\1709535596.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.loc[:, f_columns] = f_transformer.transform(test[f_columns].to_numpy())
# C:\Users\kevin\AppData\Local\Temp\ipykernel_40260\1709535596.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['cnt'] = cnt_transformer.transform(test[['cnt']])

# %%
def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X.iloc[i:(i + time_steps)].values
        Xs.append(v)        
        ys.append(y.iloc[i + time_steps])
    return np.array(Xs), np.array(ys)

# %%
time_steps = 10

# reshape to [samples, time_steps, n_features]

X_train, y_train = create_dataset(train, train.cnt, time_steps)
X_test, y_test = create_dataset(test, test.cnt, time_steps)

print(X_train.shape, y_train.shape)
# Out:
# (15662, 10, 13) (15662,)

# %% [markdown]
# # 先從簡單的開始

# %%
model = Sequential()
model.add(LSTM(units=128 , input_shape=(X_train.shape[1],X_train.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(Dense(units=1 , activation="tanh"))
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10, 128)           72704
#
#  dropout (Dropout)           (None, 10, 128)           0
#
#  dense (Dense)               (None, 10, 1)             129
#
# =================================================================
# Total params: 72,833
# Trainable params: 72,833
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = Sequential()
model.add(LSTM(units=128 , input_shape=(X_train.shape[1],X_train.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=70 , activation="tanh" , return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50 , activation="tanh" , return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=25 , activation="tanh" , return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1))
# model.add(Dense(units=1 , activation="tanh"))
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 10, 128)           72704
#
#  dropout_1 (Dropout)         (None, 10, 128)           0
#
#  lstm_2 (LSTM)               (None, 10, 70)            55720
#
#  dropout_2 (Dropout)         (None, 10, 70)            0
#
#  lstm_3 (LSTM)               (None, 10, 50)            24200
#
#  dropout_3 (Dropout)         (None, 10, 50)            0
#
#  lstm_4 (LSTM)               (None, 25)                7600
#
#  dropout_4 (Dropout)         (None, 25)                0
#
#  dense_1 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 160,250
# Trainable params: 160,250
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model.add(Bidirectional(LSTM(128, return_sequences=True),input_shape=(X_train.shape[1], X_train.shape[2])))

# %% [markdown]
# ＃

# %%
# model = keras.Sequential()
# model.add(
#   keras.layers.Bidirectional(
#     keras.layers.LSTM(
#       units=128, 
#       input_shape=(X_train.shape[1], X_train.shape[2])
#     )
#   )
# )
# model.add(keras.layers.Dropout(rate=0.2))
# model.add(keras.layers.Dense(units=1))
# model.compile(loss='mean_squared_error', optimizer='adam')

# %%
history = model.fit(
    X_train, y_train, 
    epochs=30, 
    batch_size=32, 
    validation_split=0.1,
    shuffle=False
)
# Out:
# Epoch 1/30
# 441/441 [==============================] - 15s 15ms/step - loss: 0.4330 - val_loss: 0.4767
# Epoch 2/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.2174 - val_loss: 0.4062
# Epoch 3/30
# 441/441 [==============================] - 6s 13ms/step - loss: 0.1946 - val_loss: 0.3385
# Epoch 4/30
# 441/441 [==============================] - 5s 12ms/step - loss: 0.1512 - val_loss: 0.2772
# Epoch 5/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.1229 - val_loss: 0.1895
# Epoch 6/30
# 441/441 [==============================] - 5s 10ms/step - loss: 0.1063 - val_loss: 0.1562
# Epoch 7/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0997 - val_loss: 0.1271
# Epoch 8/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0920 - val_loss: 0.1203
# Epoch 9/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0833 - val_loss: 0.1179
# Epoch 10/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0757 - val_loss: 0.1149
# Epoch 11/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0720 - val_loss: 0.0965
# Epoch 12/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0662 - val_loss: 0.1556
# Epoch 13/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0649 - val_loss: 0.1209
# Epoch 14/30
# 441/441 [==============================] - 5s 11ms/step - loss: 0.0601 - val_loss: 0.1089
# Epoch 15/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0567 - val_loss: 0.1467
# Epoch 16/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0523 - val_loss: 0.1470
# Epoch 17/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0508 - val_loss: 0.1189
# Epoch 18/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0486 - val_loss: 0.1165
# Epoch 19/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0464 - val_loss: 0.1208
# Epoch 20/30
# 441/441 [==============================] - 5s 10ms/step - loss: 0.0455 - val_loss: 0.1033
# Epoch 21/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0446 - val_loss: 0.0923
# Epoch 22/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0451 - val_loss: 0.0629
# Epoch 23/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0424 - val_loss: 0.0648
# Epoch 24/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0430 - val_loss: 0.0712
# Epoch 25/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0391 - val_loss: 0.0863
# Epoch 26/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0411 - val_loss: 0.0561
# Epoch 27/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0414 - val_loss: 0.0618
# Epoch 28/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0377 - val_loss: 0.0928
# Epoch 29/30
# 441/441 [==============================] - 5s 10ms/step - loss: 0.0379 - val_loss: 0.0463
# Epoch 30/30
# 441/441 [==============================] - 4s 10ms/step - loss: 0.0395 - val_loss: 0.0550

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend();

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import mean_squared_log_error
from sklearn.metrics import mean_absolute_error

# %%
print('test MSE：',mean_squared_error(model.predict(X_test),y_test))
print('test RMSE：',np.sqrt(mean_squared_error(model.predict(X_test),y_test)))
# Out:
# 55/55 [==============================] - 1s 4ms/step
# test MSE： 0.08138099661744704
# 55/55 [==============================] - 0s 4ms/step
# test RMSE： 0.2852735469990988

# %%
#predict結果
y_pred = model.predict(X_test)
# Out:
# 55/55 [==============================] - 0s 4ms/step

# %%
y_train_inv = cnt_transformer.inverse_transform(y_train.reshape(1, -1))
y_test_inv = cnt_transformer.inverse_transform(y_test.reshape(1, -1))
y_pred_inv = cnt_transformer.inverse_transform(y_pred)

# %%
#plot結果
plt.plot(np.arange(0, len(y_train)), y_train_inv.flatten(), 'g', label="history")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test_inv.flatten(), marker='.', label="true")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_pred_inv.flatten(), 'r', label="prediction")
plt.ylabel('Bike Count')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
#plot test 結果
plt.plot(y_test_inv.flatten(), marker='.', label="true")
plt.plot(y_pred_inv.flatten(), 'r', label="prediction")
plt.ylabel('Bike Count')
plt.xlabel('Time Step')
plt.legend()
plt.show();
